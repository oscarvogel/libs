# %%
import arcovid19

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
arcovid19.CACHE.clear()
# Out:
# 1

# %%
# %%time
cases = arcovid19.load_cases()
# Out:
# CPU times: user 190 ms, sys: 1.92 ms, total: 192 ms
# Wall time: 226 ms

# %%
fig, ax = plt.subplots(figsize=(20, 4))
cases.plot(ax=ax, confirmed=False, recovered=True)

# %%
ax = cases.plot.grate_full_period()
